# %%
# 타이타닉 호 승객 생존 예측 미니 프로젝트 : 1. EDA(분석 + 시각화)

# %%
import warnings
warnings.filterwarnings("ignore") # 경고 무시

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("titanic.csv")
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male  30.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female  25.0000      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542      NaN        C  NaN
# 1305  female      NaN      1      0    2665   14.4542      NaN        C  NaN
# 1306    male  26.5000      0      0    2656    7.2250      NaN        C  NaN
# 1307    male  27.0000      0      0    2670    7.2250      NaN        C  NaN
# 1308    male  29.0000      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
df.boxplot()
plt.show()

# %%
df[ ['age','sibsp','parch'] ].boxplot()
plt.show()

# %%
sns.boxplot(data=df)
plt.savefig('pic01.png')
plt.show()

# %%
sns.violinplot(df)
plt.show()

# %%
df[ ['age','fare'] ].hist(figsize=(10, 4), bins=20)
plt.show()

# %%
# 결측치 갯수 확인

# %%
df.isnull()
# Out:
#       pclass  survived   name    sex    age  sibsp  parch  ticket   fare  \
# 0      False     False  False  False  False  False  False   False  False
# 1      False     False  False  False  False  False  False   False  False
# 2      False     False  False  False  False  False  False   False  False
# 3      False     False  False  False  False  False  False   False  False
# 4      False     False  False  False  False  False  False   False  False
# ...      ...       ...    ...    ...    ...    ...    ...     ...    ...
# 1304   False     False  False  False  False  False  False   False  False
# 1305   False     False  False  False   True  False  False   False  False
# 1306   False     False  False  False  False  False  False   False  False
# 1307   False     False  False  False  False  False  False   False  False
# 1308   False     False  False  False  False  False  False   False  False
#
#       cabin  embarked   boat   body  home.dest
# 0     False     False  False   True      False
# 1     False     False  False   True      False
# 2     False     False   True   True      False
# 3     False     False   True  False      False
# 4     False     False   True   True      False
# ...     ...       ...    ...    ...        ...
# 1304   True     False   True  False       True
# 1305   True     False   True   True       True
# 1306   True     False   True  False       True
# 1307   True     False   True   True       True
# 1308   True     False   True   True       True
#
# [1309 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
missing_counts = df.isnull().sum()
ax = missing_counts.plot(kind='bar', rot=45)
ax.bar_label(ax.containers[0])  # container 지정!
plt.show()

# %%
# missingno 라이브러리가 설치되어 있지 않으면 설치하라!
try:
    import missingno
except:
    ! pip install missingno

# %%
import missingno as mn

# %%
mn.bar(df)
plt.show()

# %%
mn.matrix(df)
plt.show()

# %%
# 결측치 찾기

# %%
df['fare'] # Series : 인덱스가 있는 1차원 데이터
# Out:
# 0       211.3375
# 1       151.5500
# 2       151.5500
# 3       151.5500
# 4       151.5500
#           ...
# 1304     14.4542
# 1305     14.4542
# 1306      7.2250
# 1307      7.2250
# 1308      7.8750
# Name: fare, Length: 1309, dtype: float64

# %%
df['fare'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1304    False
# 1305    False
# 1306    False
# 1307    False
# 1308    False
# Name: fare, Length: 1309, dtype: bool

# %%
# df[ 조건 ]
df[ df['fare'].isnull() ]
# Out:
#       pclass  survived                name   sex   age  sibsp  parch ticket  \
# 1225       3         0  Storey, Mr. Thomas  male  60.5      0      0   3701
#
#       fare cabin embarked boat   body home.dest
# 1225   NaN   NaN        S  NaN  261.0       NaN

# %%
# 나이가 75세 이상인 승객 찾기
# df[ 조건 ]
df[ df['age'] >= 75 ]
# Out:
#     pclass  survived                                               name  \
# 14       1         1               Barkworth, Mr. Algernon Henry Wilson
# 61       1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
#
#        sex   age  sibsp  parch ticket   fare cabin embarked boat  body  \
# 14    male  80.0      0      0  27042  30.00   A23        S    B   NaN
# 61  female  76.0      1      0  19877  78.85   C46        S    6   NaN
#
#                   home.dest
# 14            Hessle, Yorks
# 61  Little Onn Hall, Staffs

# %%
# 나이가 75세 이상이면서(AND, &) 여성인 승객 찾기
# df[ ( 조건1 ) & ( 조건2 ) ]
df[ (df['age'] >= 75) & (df['sex'] == 'female') ]
# Out:
#     pclass  survived                                               name  \
# 61       1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
#
#        sex   age  sibsp  parch ticket   fare cabin embarked boat  body  \
# 61  female  76.0      1      0  19877  78.85   C46        S    6   NaN
#
#                   home.dest
# 61  Little Onn Hall, Staffs

# %%
# 생존자 수와 사망자 수 확인
df['survived'].value_counts()
# Out:
# survived
# 0    809
# 1    500
# Name: count, dtype: int64

# %%
# 남자와 여자 수
df['sex'].value_counts()
# Out:
# sex
# male      843
# female    466
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
df['survived'].value_counts().plot.pie(explode=[0,0.1], autopct="%.2f%%", shadow=True,
                                       startangle=90)
plt.subplot(122)
sns.countplot(data=df, x='survived', hue='survived')
plt.show()

# %%
# 한글깨짐 해결, 원인:디폴트 영문글꼴==>한글글꼴
import matplotlib.pyplot as plt
import platform
if platform.system() == 'Windows': # W:대문자
    plt.rcParams['font.family'] = 'Malgun Gothic' # M,G:대문자, 중간에 스페이스 한칸
elif platform.system() == 'Darwin': # 맥OS, D:대문자
    plt.rcParams['font.family'] = 'AppleGothic'
else: # 리눅스
    plt.rcParams['font.family'] = 'NanumGothic'
# -(마이너스 기호) 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
df['survived'].value_counts().plot.pie(explode=[0,0.1], autopct="%.2f%%", shadow=True,
                                       startangle=90, labels=['사망','생존'])
plt.subplot(122)
ax = sns.countplot(data=df, x='survived', hue='survived')
for i in ax.containers:
    ax.bar_label(i)
plt.show()

# %%
# 나이 그래프에 숫자 표시하기
_, _, bars = plt.hist(df['age'], bins=20)
plt.bar_label(bars)
plt.show()

# %%
# 성별에 따른 생존자 수와 사망자 수 확인
df.groupby( ['sex', 'survived'] )['survived'].count()
# Out:
# sex     survived
# female  0           127
#         1           339
# male    0           682
#         1           161
# Name: survived, dtype: int64

# %%
# 성별에 따른 생존의 평균
df[ ['sex','survived'] ].groupby('sex').mean()
# Out:
#         survived
# sex
# female  0.727468
# male    0.190985

# %%
# 선실등급별 생존 정보 확인
pd.crosstab( df['pclass'], df['survived'] ) # ( 행, 열 )
# Out:
# survived    0    1
# pclass
# 1         123  200
# 2         158  119
# 3         528  181

# %%
ax = pd.crosstab( df['pclass'], df['survived'] ).plot.bar(rot=0)
for i in ax.containers:
    ax.bar_label(i)
plt.show()

# %%
sns.pointplot(df, x='pclass', y='survived')
plt.show()

# %%
sns.pointplot(df, x='pclass', y='survived', hue='sex')
plt.show()

# %%
# 상관계수 : -1 ~ 0 ~ 1

# %%
df.corr(numeric_only=True)
# Out:
#             pclass  survived       age     sibsp     parch      fare      body
# pclass    1.000000 -0.312469 -0.408106  0.060832  0.018322 -0.558629 -0.034642
# survived -0.312469  1.000000 -0.055513 -0.027825  0.082660  0.244265       NaN
# age      -0.408106 -0.055513  1.000000 -0.243699 -0.150917  0.178739  0.058809
# sibsp     0.060832 -0.027825 -0.243699  1.000000  0.373587  0.160238 -0.099961
# parch     0.018322  0.082660 -0.150917  0.373587  1.000000  0.221539  0.051099
# fare     -0.558629  0.244265  0.178739  0.160238  0.221539  1.000000 -0.043110
# body     -0.034642       NaN  0.058809 -0.099961  0.051099 -0.043110  1.000000

# %%
sns.heatmap(df.corr(numeric_only=True), linewidths=0.1, annot=True)
plt.show()

# %%
# 나이(age, 실수) ==> 범주형
# df['추가할_컬럼명'] = 계산식(컬럼, 범위, 라벨)
df['age_cat'] = pd.cut(df['age'], bins=[0,5,12,19,39,59,80],
                      labels=['Baby','Child','Teenager','YoungAdult','Adult','Senior'])
#0~5:Baby, 6~12:Child, 13~19:Teenager, 20~39:YoungAdult, 40~59:Adult, 60~80:Senior
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male  30.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female  25.0000      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542      NaN        C  NaN
# 1305  female      NaN      1      0    2665   14.4542      NaN        C  NaN
# 1306    male  26.5000      0      0    2656    7.2250      NaN        C  NaN
# 1307    male  27.0000      0      0    2670    7.2250      NaN        C  NaN
# 1308    male  29.0000      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest     age_cat
# 0       NaN                     St Louis, MO  YoungAdult
# 1       NaN  Montreal, PQ / Chesterville, ON        Baby
# 2       NaN  Montreal, PQ / Chesterville, ON        Baby
# 3     135.0  Montreal, PQ / Chesterville, ON  YoungAdult
# 4       NaN  Montreal, PQ / Chesterville, ON  YoungAdult
# ...     ...                              ...         ...
# 1304  328.0                              NaN    Teenager
# 1305    NaN                              NaN         NaN
# 1306  304.0                              NaN  YoungAdult
# 1307    NaN                              NaN  YoungAdult
# 1308    NaN                              NaN  YoungAdult
#
# [1309 rows x 15 columns]

# %%
# 나이(age, 실수) ==> 범주형
# df['추가할_컬럼명'] = 계산식(컬럼, 범위, 라벨)
df['age_cat'] = pd.cut(df['age'], bins=[0,5,12,19,39,59,80],
                      labels=['Baby','Child','Teenager','YoungAdult','Adult','Senior'])
#0~5:Baby, 6~12:Child, 13~19:Teenager, 20~39:YoungAdult, 40~59:Adult, 60~80:Senior
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male  30.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female  25.0000      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542      NaN        C  NaN
# 1305  female      NaN      1      0    2665   14.4542      NaN        C  NaN
# 1306    male  26.5000      0      0    2656    7.2250      NaN        C  NaN
# 1307    male  27.0000      0      0    2670    7.2250      NaN        C  NaN
# 1308    male  29.0000      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest     age_cat
# 0       NaN                     St Louis, MO  YoungAdult
# 1       NaN  Montreal, PQ / Chesterville, ON        Baby
# 2       NaN  Montreal, PQ / Chesterville, ON        Baby
# 3     135.0  Montreal, PQ / Chesterville, ON  YoungAdult
# 4       NaN  Montreal, PQ / Chesterville, ON  YoungAdult
# ...     ...                              ...         ...
# 1304  328.0                              NaN    Teenager
# 1305    NaN                              NaN         NaN
# 1306  304.0                              NaN  YoungAdult
# 1307    NaN                              NaN  YoungAdult
# 1308    NaN                              NaN  YoungAdult
#
# [1309 rows x 15 columns]

# %%
# 운임(fare, 실수) ==> 운임대(범주형)
bins = [ 0, 10, 30, 100, 600 ]
labels = [ 'Low', 'Medium', 'High', 'Very High' ]
df['fare_cat'] = pd.cut(df['fare'], bins=bins, labels=labels)
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male  30.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female  25.0000      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542      NaN        C  NaN
# 1305  female      NaN      1      0    2665   14.4542      NaN        C  NaN
# 1306    male  26.5000      0      0    2656    7.2250      NaN        C  NaN
# 1307    male  27.0000      0      0    2670    7.2250      NaN        C  NaN
# 1308    male  29.0000      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest     age_cat   fare_cat
# 0       NaN                     St Louis, MO  YoungAdult  Very High
# 1       NaN  Montreal, PQ / Chesterville, ON        Baby  Very High
# 2       NaN  Montreal, PQ / Chesterville, ON        Baby  Very High
# 3     135.0  Montreal, PQ / Chesterville, ON  YoungAdult  Very High
# 4       NaN  Montreal, PQ / Chesterville, ON  YoungAdult  Very High
# ...     ...                              ...         ...        ...
# 1304  328.0                              NaN    Teenager     Medium
# 1305    NaN                              NaN         NaN     Medium
# 1306  304.0                              NaN  YoungAdult        Low
# 1307    NaN                              NaN  YoungAdult        Low
# 1308    NaN                              NaN  YoungAdult        Low
#
# [1309 rows x 16 columns]

# %%
# 최종 그래프 : 선실등급, 연령대, 성별, 운임대에 따른 생존 그래프

# %%
plt.figure(figsize=(18, 4))
plt.subplot(141)
ax = sns.barplot(df, x='pclass', y='survived', errorbar=None, hue='pclass', palette='tab10')
for bars in ax.containers:
    ax.bar_label(bars, fmt='{:.2%}')
plt.subplot(142)
ax = sns.barplot(df, x='age_cat', y='survived', errorbar=None, hue='age_cat', palette='tab10',
                legend=False)
for bars in ax.containers:
    ax.bar_label(bars, fmt='{:.2%}')
plt.xticks(rotation=45)
plt.subplot(143)
ax = sns.barplot(df, x='sex', y='survived', errorbar=None, hue='sex', palette='tab10',
                legend=True)
for bars in ax.containers:
    ax.bar_label(bars, fmt='{:.2%}')
plt.subplot(144)
ax = sns.barplot(df, x='fare_cat', y='survived', errorbar=None, hue='fare_cat',
                 palette='tab10', legend=True)
for bars in ax.containers:
    ax.bar_label(bars, fmt='{:.2%}')
plt.show()

# %%
# end
